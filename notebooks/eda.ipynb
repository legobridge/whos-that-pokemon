# %%
import pandas as pd

# %%
df = pd.read_csv('../data/pokemon.csv')
df
# Out:
#                       name  pokedex_number             abilities  \
# 0                Bulbasaur               1  Overgrow~Chlorophyll
# 1                  Ivysaur               2  Overgrow~Chlorophyll
# 2                 Venusaur               3  Overgrow~Chlorophyll
# 3            Venusaur Gmax               3  Overgrow~Chlorophyll
# 4            Venusaur Mega               3             Thick Fat
# ...                    ...             ...                   ...
# 1113             Glastrier             896        Chilling Neigh
# 1114             Spectrier             897            Grim Neigh
# 1115               Calyrex             898               Unnerve
# 1116     Calyrex Ice Rider             898                As One
# 1117  Calyrex Shadow Rider             898                As One
#
#              typing   hp  attack  defense  special_attack  special_defense  \
# 0      Grass~Poison   45      49       49              65               65
# ...

# %%
# remove non-default and > gen 2 pokemon
filtered_df = df[(df['pokedex_number'] <= 251) & (df['is_default'] == True)].reset_index(drop=True)
filtered_df
# Out:
#            name  pokedex_number             abilities          typing   hp  \
# 0     Bulbasaur               1  Overgrow~Chlorophyll    Grass~Poison   45
# 1       Ivysaur               2  Overgrow~Chlorophyll    Grass~Poison   60
# 2      Venusaur               3  Overgrow~Chlorophyll    Grass~Poison   80
# 3    Charmander               4     Blaze~Solar Power            Fire   39
# 4    Charmeleon               5     Blaze~Solar Power            Fire   58
# ..          ...             ...                   ...             ...  ...
# 246     Pupitar             247             Shed Skin     Rock~Ground   70
# 247   Tyranitar             248   Sand Stream~Unnerve       Rock~Dark  100
# 248       Lugia             249   Pressure~Multiscale  Psychic~Flying  106
# 249       Ho Oh             250  Pressure~Regenerator     Fire~Flying  106
# 250      Celebi             251          Natural Cure   Psychic~Grass  100
#
#      attack  defense  special_attack  special_defense  speed  ...  \
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           251 non-null    object
#  1   pokedex_number                 251 non-null    int64
#  2   abilities                      251 non-null    object
#  3   typing                         251 non-null    object
#  4   hp                             251 non-null    int64
#  5   attack                         251 non-null    int64
#  6   defense                        251 non-null    int64
#  7   special_attack                 251 non-null    int64
#  8   special_defense                251 non-null    int64
#  9   speed                          251 non-null    int64
#  10  height                         251 non-null    int64
#  11  weight                         251 non-null    int64
# ...

# %%
# save to disk
filtered_df.to_csv('../data/pokemon_gen_1-2.csv', index=False)

# %%
columns_to_keep = ["name","pokedex_number","typing","number_pokemon_with_typing","can_evolve","evolves_from","primary_color","shape","height","weight","legendary","genus","gen_introduced","normal_attack_effectiveness","fire_attack_effectiveness","water_attack_effectiveness","electric_attack_effectiveness","grass_attack_effectiveness","ice_attack_effectiveness","fighting_attack_effectiveness","poison_attack_effectiveness","ground_attack_effectiveness","fly_attack_effectiveness","psychic_attack_effectiveness","bug_attack_effectiveness","rock_attack_effectiveness","ghost_attack_effectiveness","dragon_attack_effectiveness","dark_attack_effectiveness","steel_attack_effectiveness"]
few_col_df = filtered_df[columns_to_keep]
few_col_df
# Out:
#            name  pokedex_number          typing  number_pokemon_with_typing  \
# 0     Bulbasaur               1    Grass~Poison                        15.0
# 1       Ivysaur               2    Grass~Poison                        15.0
# 2      Venusaur               3    Grass~Poison                        15.0
# 3    Charmander               4            Fire                        34.0
# 4    Charmeleon               5            Fire                        34.0
# ..          ...             ...             ...                         ...
# 246     Pupitar             247     Rock~Ground                         9.0
# 247   Tyranitar             248       Rock~Dark                         2.0
# 248       Lugia             249  Psychic~Flying                         8.0
# 249       Ho Oh             250     Fire~Flying                         7.0
# 250      Celebi             251   Psychic~Grass                         4.0
#
# ...

# %%
few_col_df['shape'].unique()
# Out:
# array(['Quadruped', 'Upright', 'Armor', 'Squiggle', 'Bug-Wings', 'Wings',
#        'Humanoid', 'Legs', 'Blob', 'Heads', 'Tentacles', 'Arms', 'Fish',
#        'Ball'], dtype=object)

# %%
few_col_df[['name', 'shape']].head(60)
# Out:
#           name      shape
# 0    Bulbasaur  Quadruped
# 1      Ivysaur  Quadruped
# 2     Venusaur  Quadruped
# 3   Charmander    Upright
# 4   Charmeleon    Upright
# 5    Charizard    Upright
# 6     Squirtle    Upright
# 7    Wartortle    Upright
# 8    Blastoise    Upright
# 9     Caterpie      Armor
# 10     Metapod   Squiggle
# 11  Butterfree  Bug-Wings
# 12      Weedle      Armor
# 13      Kakuna   Squiggle
# 14    Beedrill  Bug-Wings
# 15      Pidgey      Wings
# 16   Pidgeotto      Wings
# 17     Pidgeot      Wings
# 18     Rattata  Quadruped
# 19    Raticate  Quadruped
# 20     Spearow      Wings
# 21      Fearow      Wings
# 22       Ekans   Squiggle
# 23       Arbok   Squiggle
# 24     Pikachu  Quadruped
# 25      Raichu    Upright
# 26   Sandshrew    Upright
# 27   Sandslash    Upright
# 28   Nidoran F  Quadruped
# 29    Nidorina  Quadruped
# 30   Nidoqueen    Upright
# 31   Nidoran M  Quadruped
# 32    Nidorino  Quadruped
# 33    Nidoking    Upright
# ...

# %%
few_col_df[few_col_df['shape'] == 'Armor']
# Out:
#          name  pokedex_number      typing  number_pokemon_with_typing  \
# 9    Caterpie              10         Bug                        19.0
# 12     Weedle              13  Bug~Poison                        13.0
# 45      Paras              46   Bug~Grass                         6.0
# 46   Parasect              47   Bug~Grass                         6.0
# 97     Krabby              98       Water                        72.0
# 98    Kingler              99       Water                        72.0
# 139    Kabuto             140  Rock~Water                        11.0
# 166  Spinarak             167  Bug~Poison                        13.0
# 167   Ariados             168  Bug~Poison                        13.0
# 212   Shuckle             213    Bug~Rock                         5.0
# 221   Corsola             222  Water~Rock                        11.0
#
#      can_evolve evolves_from primary_color  shape  height  weight  ...  \
# ...

# %%
few_col_df[few_col_df['shape'] == 'Bug-Wings']
# Out:
#            name  pokedex_number         typing  number_pokemon_with_typing  \
# 11   Butterfree              12     Bug~Flying                        14.0
# 14     Beedrill              15     Bug~Poison                        13.0
# 48     Venomoth              49     Bug~Poison                        13.0
# 122     Scyther             123     Bug~Flying                        14.0
# 168      Crobat             169  Poison~Flying                         3.0
# 192       Yanma             193     Bug~Flying                        14.0
# 211      Scizor             212      Bug~Steel                         7.0
#
#      can_evolve evolves_from primary_color      shape  height  weight  ...  \
# 11        False      Metapod         White  Bug-Wings      11     320  ...
# 14        False       Kakuna        Yellow  Bug-Wings      10     295  ...
# 48        False      Venonat        Purple  Bug-Wings      15     125  ...
# ...

# %%
few_col_df[few_col_df['shape'] == 'Bug-Wings']
# Out:
#            name  pokedex_number         typing  number_pokemon_with_typing  \
# 11   Butterfree              12     Bug~Flying                        14.0
# 14     Beedrill              15     Bug~Poison                        13.0
# 48     Venomoth              49     Bug~Poison                        13.0
# 122     Scyther             123     Bug~Flying                        14.0
# 168      Crobat             169  Poison~Flying                         3.0
# 192       Yanma             193     Bug~Flying                        14.0
# 211      Scizor             212      Bug~Steel                         7.0
#
#      can_evolve evolves_from primary_color      shape  height  weight  ...  \
# 11        False      Metapod         White  Bug-Wings      11     320  ...
# 14        False       Kakuna        Yellow  Bug-Wings      10     295  ...
# 48        False      Venonat        Purple  Bug-Wings      15     125  ...
# ...

# %%
few_col_df[few_col_df['name'] == 'Charizard']
# Out:
#         name  pokedex_number       typing  number_pokemon_with_typing  \
# 5  Charizard               6  Fire~Flying                         7.0
#
#    can_evolve evolves_from primary_color    shape  height  weight  ...  \
# 5       False   Charmeleon           Red  Upright      17     905  ...
#
#    poison_attack_effectiveness ground_attack_effectiveness  \
# 5                          1.0                         0.0
#
#    fly_attack_effectiveness  psychic_attack_effectiveness  \
# 5                       1.0                           1.0
#
#    bug_attack_effectiveness  rock_attack_effectiveness  \
# 5                      0.25                        4.0
#
#    ghost_attack_effectiveness  dragon_attack_effectiveness  \
# 5                         1.0                          1.0
#
#    dark_attack_effectiveness  steel_attack_effectiveness
# 5                        1.0                         0.5
#
# [1 rows x 30 columns]
