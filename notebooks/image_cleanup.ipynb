# %%
import pandas as pd

# %%
df = pd.read_csv('../data/pokemonDataLatest.csv')
df
# Out:
#            name  pokedex_number   type_1  type_2  number_pokemon_with_typing  \
# 0     Bulbasaur               1    Grass  Poison                          15
# 1       Ivysaur               2    Grass  Poison                          15
# 2      Venusaur               3    Grass  Poison                          15
# 3    Charmander               4     Fire     NaN                          34
# 4    Charmeleon               5     Fire     NaN                          34
# ..          ...             ...      ...     ...                         ...
# 246     Pupitar             247     Rock  Ground                           9
# 247   Tyranitar             248     Rock    Dark                           2
# 248       Lugia             249  Psychic  Flying                           8
# 249       Ho Oh             250     Fire  Flying                           7
# 250      Celebi             251  Psychic   Grass                           4
#
# ...

# %%
import os

# %%
for name in df.name:
    if not os.path.exists(f'../data/pokemon_images/{name.lower()}.png'):
        print(name)
# Out:
# Nidoran F
# Nidoran M
# Mr Mime
# Unown
# Ho Oh

# %%
in df.name.str.lower()
# Out:
# True

# %%
len(os.listdir('../data/pokemon_images/'))
# Out:
# 252

# %%
for image_name in os.listdir('../data/pokemon_images/'):
    if '.png' not in image_name:
        continue
    pkmn_name, _ = image_name.split('.')
    if pkmn_name not in df.name.str.lower().str.replace(' ', '').values:
        os.remove(f'../data/pokemon_images/{image_name}')
