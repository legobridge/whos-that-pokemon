# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('../data/PokemonDataLatest.csv')

print("------It Weighs-------")
itWeighsdict = {
    'veryLight': 50,
    'veryHeavy': 1000,
}

itWeighsList = ["itWeighs veryLight", "itWeighs veryHeavy"]
print(itWeighsList)
print("\n\n")
print("------It Has Height-------")
itHasHeight = {
    'veryShort': 7,
    'veryTall': 25
}

itHasHeightList = ["itHasHeight veryShort", "itHasHeight veryTall"]
print(itHasHeightList)
print("\n\n")
list_of_types1 = data.type_1.unique()
type1list = ["isType " + l for l in list_of_types1]
print("-------Type 1 List-------")
print(type1list)
print("\n\n")
print("-------Type 2 List-------")
list_of_types2 = [x for x in data.type_2.unique() if str(x) != 'nan']
type2list = ["isType " + l for l in list_of_types2]
print(type2list)
print("\n\n")
print("-------Genus List-------")
genus = [x.split()[:-1] for x in data.genus.unique()]
genus = [''.join(x) for x in genus]
genusList = ["isGenus " + g for g in genus]
print(genusList)
print("\n\n")
print("-------Gen Introduced In List-------")
genIntroduceInList = ["wasIntroducedIn Gen" + str(g) for g in data.gen_introduced.unique()]
print(genIntroduceInList)
print("\n\n")
print("-------Legendary or Not-------")
legendaryornot = ['isLegendary']
print(legendaryornot)
print("\n\n")
print("-------Can Evolve-------")
canEvolve = ['canEvolve']
print(canEvolve)
print("\n\n")
print("-------Evolves From-------")
evolvesFrom = [x for x in data.evolves_from.unique() if str(x) != 'nan']
evolvesFromList = ["evolvesFrom " + e for e in evolvesFrom]
print(evolvesFromList)
print("\n\n")
print("-------Evolves From Something-------")
evolvesFromSomething = ['evolvesFromSomething']
print(evolvesFromSomething)
print("\n\n")
print("-------Color-------")
colorList = ["isColor " + p for p in data.primary_color.unique()]
print(colorList)
print("\n\n")
print("-------Shape-------")
shapeList = ["hasShape " + s for s in data['shape'].unique()]
print(shapeList)
print("\n\n")
print("-------Ash Owned Pokemon-------")
isAshOwnedList = ['isAshOwned']
print(isAshOwnedList)
print("\n\n")
print("-------IsPrimaryColor-------")
primaryColors = ["red","blue","yellow"]
isPrimaryColorList = ["isPrimaryColor"]
print(isPrimaryColorList)
print("\n\n")
print("-------Attack Effectiveness-------")
effectiveList = list(list())
effectivenessTypeList=['super_effective','not_very_effective','has_no_effect']
for col in data.columns:
    if 'attack_effectiveness' in col:
        howEffectiveList=[]
        for h in effectivenessTypeList:
            howEffectiveList.append("howEffective " + col.split("_")[0].capitalize() + " " + h)
        effectiveList.append(howEffectiveList)
        print("--- how effective is "+col.split("_")[0].capitalize()+" attack against this pokemon ---")
        print(howEffectiveList)
        print("\n\n")
print("-------Pokemon name-------")
pokemonNameList = ["Pokemon"]
print(pokemonNameList)
print("\n\n")
# Out:
# ------It Weighs-------
# ['itWeighs veryLight', 'itWeighs veryHeavy']
#
#
#
# ------It Has Height-------
# ['itHasHeight veryShort', 'itHasHeight veryTall']
#
#
#
# -------Type 1 List-------
# ['isType Grass', 'isType Fire', 'isType Water', 'isType Bug', 'isType Normal', 'isType Poison', 'isType Electric', 'isType Ground', 'isType Fairy', 'isType Fighting', 'isType Psychic', 'isType Rock', 'isType Ghost', 'isType Ice', 'isType Dragon', 'isType Dark', 'isType Steel']
#
#
#
# -------Type 2 List-------
# ['isType Poison', 'isType Flying', 'isType Ground', 'isType Fairy', 'isType Grass', 'isType Fighting', 'isType Psychic', 'isType Steel', 'isType Ice', 'isType Rock', 'isType Water', 'isType Electric', 'isType Fire', 'isType Dragon', 'isType Dark']
#
#
#
# -------Genus List-------
# ['isGenus Seed', 'isGenus Lizard', 'isGenus Flame', 'isGenus TinyTurtle', 'isGenus Turtle', 'isGenus Shellfish', 'isGenus Worm', 'isGenus Cocoon', 'isGenus Butterfly', 'isGenus HairyBug', 'isGenus PoisonBee', 'isGenus TinyBird', 'isGenus Bird', 'isGenus Mouse', 'isGenus Beak', 'isGenus Snake', 'isGenus Cobra', 'isGenus PoisonPin', 'isGenus Drill', 'isGenus Fairy', 'isGenus Fox', 'isGenus Balloon', 'isGenus Bat', 'isGenus Weed', 'isGenus Flower', 'isGenus Mushroom', 'isGenus Insect', 'isGenus PoisonMoth', 'isGenus Mole', 'isGenus ScratchCat', 'isGenus ClassyCat', 'isGenus Duck', 'isGenus PigMonkey', 'isGenus Puppy', 'isGenus Legendary', 'isGenus Tadpole', 'isGenus Psi', 'isGenus Superpower', 'isGenus Flycatcher', 'isGenus Jellyfish', 'isGenus Rock', 'isGenus Megaton', 'isGenus FireHorse', 'isGenus Dopey', 'isGenus HermitCrab', 'isGenus Magnet', 'isGenus WildDuck', 'isGenus TwinBird', 'isGenus TripleBird', 'isGenus SeaLion', 'isGenus Sludge', 'isGenus Bivalve', 'isGenus Gas', 'isGenus Shadow', 'isGenus RockSnake', 'isGenus Hypnosis', 'isGenus RiverCrab', 'isGenus Pincer', 'isGenus Ball', 'isGenus Egg', 'isGenus Coconut', 'isGenus Lonely', 'isGenus BoneKeeper', 'isGenus Kicking', 'isGenus Punching', 'isGenus Licking', 'isGenus PoisonGas', 'isGenus Spikes', 'isGenus Vine', 'isGenus Parent', 'isGenus Dragon', 'isGenus Goldfish', 'isGenus StarShape', 'isGenus Mysterious', 'isGenus Barrier', 'isGenus Mantis', 'isGenus HumanShape', 'isGenus Electric', 'isGenus Spitfire', 'isGenus StagBeetle', 'isGenus WildBull', 'isGenus Fish', 'isGenus Atrocious', 'isGenus Transport', 'isGenus Transform', 'isGenus Evolution', 'isGenus BubbleJet', 'isGenus Lightning', 'isGenus Virtual', 'isGenus Spiral', 'isGenus Fossil', 'isGenus Sleeping', 'isGenus Freeze', 'isGenus Genetic', 'isGenus NewSpecies', 'isGenus Leaf', 'isGenus Herb', 'isGenus FireMouse', 'isGenus Volcano', 'isGenus BigJaw', 'isGenus Scout', 'isGenus LongBody', 'isGenus Owl', 'isGenus FiveStar', 'isGenus StringSpit', 'isGenus LongLeg', 'isGenus Angler', 'isGenus Light', 'isGenus TinyMouse', 'isGenus SpikeBall', 'isGenus Happiness', 'isGenus Mystic', 'isGenus Wool', 'isGenus AquaMouse', 'isGenus AquaRabbit', 'isGenus Imitation', 'isGenus Frog', 'isGenus Cottonweed', 'isGenus LongTail', 'isGenus Sun', 'isGenus ClearWing', 'isGenus WaterFish', 'isGenus Moonlight', 'isGenus Darkness', 'isGenus Royal', 'isGenus Screech', 'isGenus Symbol', 'isGenus Patient', 'isGenus LongNeck', 'isGenus Bagworm', 'isGenus LandSnake', 'isGenus FlyScorpion', 'isGenus IronSnake', 'isGenus Mold', 'isGenus SingleHorn', 'isGenus SharpClaw', 'isGenus LittleBear', 'isGenus Hibernator', 'isGenus Lava', 'isGenus Pig', 'isGenus Swine', 'isGenus Coral', 'isGenus Jet', 'isGenus Delivery', 'isGenus Kite', 'isGenus ArmorBird', 'isGenus Dark', 'isGenus LongNose', 'isGenus Armor', 'isGenus BigHorn', 'isGenus Painter', 'isGenus Scuffle', 'isGenus Handstand', 'isGenus Kiss', 'isGenus LiveCoal', 'isGenus MilkCow', 'isGenus Thunder', 'isGenus Aurora', 'isGenus RockSkin', 'isGenus HardShell', 'isGenus Diving', 'isGenus Rainbow', 'isGenus TimeTravel']
#
#
#
# -------Gen Introduced In List-------
# ['wasIntroducedIn Gen1', 'wasIntroducedIn Gen2']
#
#
#
# -------Legendary or Not-------
# ['isLegendary']
#
#
#
# -------Can Evolve-------
# ['canEvolve']
#
#
#
# -------Evolves From-------
# ['evolvesFrom Bulbasaur', 'evolvesFrom Ivysaur', 'evolvesFrom Charmander', 'evolvesFrom Charmeleon', 'evolvesFrom Squirtle', 'evolvesFrom Wartortle', 'evolvesFrom Caterpie', 'evolvesFrom Metapod', 'evolvesFrom Weedle', 'evolvesFrom Kakuna', 'evolvesFrom Pidgey', 'evolvesFrom Pidgeotto', 'evolvesFrom Rattata', 'evolvesFrom Spearow', 'evolvesFrom Ekans', 'evolvesFrom Pichu', 'evolvesFrom Pikachu', 'evolvesFrom Sandshrew', 'evolvesFrom Nidoran F', 'evolvesFrom Nidorina', 'evolvesFrom Nidoran M', 'evolvesFrom Nidorino', 'evolvesFrom Cleffa', 'evolvesFrom Clefairy', 'evolvesFrom Vulpix', 'evolvesFrom Igglybuff', 'evolvesFrom Jigglypuff', 'evolvesFrom Zubat', 'evolvesFrom Oddish', 'evolvesFrom Gloom', 'evolvesFrom Paras', 'evolvesFrom Venonat', 'evolvesFrom Diglett', 'evolvesFrom Meowth', 'evolvesFrom Psyduck', 'evolvesFrom Mankey', 'evolvesFrom Growlithe', 'evolvesFrom Poliwag', 'evolvesFrom Poliwhirl', 'evolvesFrom Abra', 'evolvesFrom Kadabra', 'evolvesFrom Machop', 'evolvesFrom Machoke', 'evolvesFrom Bellsprout', 'evolvesFrom Weepinbell', 'evolvesFrom Tentacool', 'evolvesFrom Geodude', 'evolvesFrom Graveler', 'evolvesFrom Ponyta', 'evolvesFrom Slowpoke', 'evolvesFrom Magnemite', 'evolvesFrom Doduo', 'evolvesFrom Seel', 'evolvesFrom Grimer', 'evolvesFrom Shellder', 'evolvesFrom Gastly', 'evolvesFrom Haunter', 'evolvesFrom Drowzee', 'evolvesFrom Krabby', 'evolvesFrom Voltorb', 'evolvesFrom Exeggcute', 'evolvesFrom Cubone', 'evolvesFrom Tyrogue', 'evolvesFrom Koffing', 'evolvesFrom Rhyhorn', 'evolvesFrom Happiny', 'evolvesFrom Horsea', 'evolvesFrom Goldeen', 'evolvesFrom Staryu', 'evolvesFrom Mime Jr', 'evolvesFrom Smoochum', 'evolvesFrom Elekid', 'evolvesFrom Magby', 'evolvesFrom Magikarp', 'evolvesFrom Eevee', 'evolvesFrom Omanyte', 'evolvesFrom Kabuto', 'evolvesFrom Munchlax', 'evolvesFrom Dratini', 'evolvesFrom Dragonair', 'evolvesFrom Chikorita', 'evolvesFrom Bayleef', 'evolvesFrom Cyndaquil', 'evolvesFrom Quilava', 'evolvesFrom Totodile', 'evolvesFrom Croconaw', 'evolvesFrom Sentret', 'evolvesFrom Hoothoot', 'evolvesFrom Ledyba', 'evolvesFrom Spinarak', 'evolvesFrom Golbat', 'evolvesFrom Chinchou', 'evolvesFrom Togepi', 'evolvesFrom Natu', 'evolvesFrom Mareep', 'evolvesFrom Flaaffy', 'evolvesFrom Azurill', 'evolvesFrom Marill', 'evolvesFrom Bonsly', 'evolvesFrom Hoppip', 'evolvesFrom Skiploom', 'evolvesFrom Sunkern', 'evolvesFrom Wooper', 'evolvesFrom Wynaut', 'evolvesFrom Pineco', 'evolvesFrom Onix', 'evolvesFrom Snubbull', 'evolvesFrom Scyther', 'evolvesFrom Teddiursa', 'evolvesFrom Slugma', 'evolvesFrom Swinub', 'evolvesFrom Remoraid', 'evolvesFrom Mantyke', 'evolvesFrom Houndour', 'evolvesFrom Seadra', 'evolvesFrom Phanpy', 'evolvesFrom Porygon', 'evolvesFrom Chansey', 'evolvesFrom Larvitar', 'evolvesFrom Pupitar']
#
#
#
# -------Evolves From Something-------
# ['evolvesFromSomething']
#
#
#
# -------Color-------
# ['isColor Green', 'isColor Red', 'isColor Blue', 'isColor White', 'isColor Brown', 'isColor Yellow', 'isColor Purple', 'isColor Pink', 'isColor Gray', 'isColor Black']
#
#
#
# -------Shape-------
# ['hasShape Quadruped', 'hasShape Upright', 'hasShape Armor', 'hasShape Squiggle', 'hasShape Bug-Wings', 'hasShape Wings', 'hasShape Humanoid', 'hasShape Legs', 'hasShape Blob', 'hasShape Heads', 'hasShape Tentacles', 'hasShape Arms', 'hasShape Fish', 'hasShape Ball']
#
#
#
# -------Ash Owned Pokemon-------
# ['isAshOwned']
#
#
#
# -------IsPrimaryColor-------
# ['isPrimaryColor']
#
#
#
# -------Attack Effectiveness-------
# --- how effective is Normal attack against this pokemon ---
# ['howEffective Normal super_effective', 'howEffective Normal not_very_effective', 'howEffective Normal has_no_effect']
#
#
#
# --- how effective is Fire attack against this pokemon ---
# ['howEffective Fire super_effective', 'howEffective Fire not_very_effective', 'howEffective Fire has_no_effect']
#
#
#
# --- how effective is Water attack against this pokemon ---
# ['howEffective Water super_effective', 'howEffective Water not_very_effective', 'howEffective Water has_no_effect']
#
#
#
# --- how effective is Electric attack against this pokemon ---
# ['howEffective Electric super_effective', 'howEffective Electric not_very_effective', 'howEffective Electric has_no_effect']
#
#
#
# --- how effective is Grass attack against this pokemon ---
# ['howEffective Grass super_effective', 'howEffective Grass not_very_effective', 'howEffective Grass has_no_effect']
#
#
#
# --- how effective is Ice attack against this pokemon ---
# ['howEffective Ice super_effective', 'howEffective Ice not_very_effective', 'howEffective Ice has_no_effect']
#
#
#
# --- how effective is Fighting attack against this pokemon ---
# ['howEffective Fighting super_effective', 'howEffective Fighting not_very_effective', 'howEffective Fighting has_no_effect']
#
#
#
# --- how effective is Poison attack against this pokemon ---
# ['howEffective Poison super_effective', 'howEffective Poison not_very_effective', 'howEffective Poison has_no_effect']
#
#
#
# --- how effective is Ground attack against this pokemon ---
# ['howEffective Ground super_effective', 'howEffective Ground not_very_effective', 'howEffective Ground has_no_effect']
#
#
#
# --- how effective is Fly attack against this pokemon ---
# ['howEffective Fly super_effective', 'howEffective Fly not_very_effective', 'howEffective Fly has_no_effect']
#
#
#
# --- how effective is Psychic attack against this pokemon ---
# ['howEffective Psychic super_effective', 'howEffective Psychic not_very_effective', 'howEffective Psychic has_no_effect']
#
#
#
# --- how effective is Bug attack against this pokemon ---
# ['howEffective Bug super_effective', 'howEffective Bug not_very_effective', 'howEffective Bug has_no_effect']
#
#
#
# --- how effective is Rock attack against this pokemon ---
# ['howEffective Rock super_effective', 'howEffective Rock not_very_effective', 'howEffective Rock has_no_effect']
#
#
#
# --- how effective is Ghost attack against this pokemon ---
# ['howEffective Ghost super_effective', 'howEffective Ghost not_very_effective', 'howEffective Ghost has_no_effect']
#
#
#
# --- how effective is Dragon attack against this pokemon ---
# ['howEffective Dragon super_effective', 'howEffective Dragon not_very_effective', 'howEffective Dragon has_no_effect']
#
#
#
# --- how effective is Dark attack against this pokemon ---
# ['howEffective Dark super_effective', 'howEffective Dark not_very_effective', 'howEffective Dark has_no_effect']
#
#
#
# --- how effective is Steel attack against this pokemon ---
# ['howEffective Steel super_effective', 'howEffective Steel not_very_effective', 'howEffective Steel has_no_effect']
#
#
#
# -------Pokemon name-------
# ['Pokemon']

# %%
data
# Out:
#            name  pokedex_number   type_1  type_2  number_pokemon_with_typing  \
# 0     Bulbasaur               1    Grass  Poison                          15
# 1       Ivysaur               2    Grass  Poison                          15
# 2      Venusaur               3    Grass  Poison                          15
# 3    Charmander               4     Fire     NaN                          34
# 4    Charmeleon               5     Fire     NaN                          34
# ..          ...             ...      ...     ...                         ...
# 246     Pupitar             247     Rock  Ground                           9
# 247   Tyranitar             248     Rock    Dark                           2
# 248       Lugia             249  Psychic  Flying                           8
# 249       Ho Oh             250     Fire  Flying                           7
# 250      Celebi             251  Psychic   Grass                           4
#
#      height  weight                genus  gen_introduced  legendary  ...  \
# 0         7      69         Seed Pokémon               1      False  ...
# 1        10     130         Seed Pokémon               1      False  ...
# 2        20    1000         Seed Pokémon               1      False  ...
# 3         6      85       Lizard Pokémon               1      False  ...
# 4        11     190        Flame Pokémon               1      False  ...
# ..      ...     ...                  ...             ...        ...  ...
# 246      12    1520   Hard Shell Pokémon               2      False  ...
# 247      20    2020        Armor Pokémon               2      False  ...
# 248      52    2160       Diving Pokémon               2       True  ...
# 249      38    1990      Rainbow Pokémon               2       True  ...
# 250       6      50  Time Travel Pokémon               2      False  ...
#
#      poison_attack_effectiveness ground_attack_effectiveness  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN             super_effective
# 4                            NaN             super_effective
# ..                           ...                         ...
# 246           not_very_effective             super_effective
# 247           not_very_effective             super_effective
# 248                          NaN               has_no_effect
# 249                          NaN               has_no_effect
# 250              super_effective          not_very_effective
#
#     fly_attack_effectiveness psychic_attack_effectiveness  \
# 0            super_effective              super_effective
# 1            super_effective              super_effective
# 2            super_effective              super_effective
# 3                        NaN                          NaN
# 4                        NaN                          NaN
# ..                       ...                          ...
# 246       not_very_effective                          NaN
# 247       not_very_effective                has_no_effect
# 248                      NaN           not_very_effective
# 249                      NaN                          NaN
# 250          super_effective           not_very_effective
#
#     bug_attack_effectiveness rock_attack_effectiveness  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3         not_very_effective           super_effective
# 4         not_very_effective           super_effective
# ..                       ...                       ...
# 246                      NaN        not_very_effective
# 247          super_effective                       NaN
# 248                      NaN           super_effective
# 249       not_very_effective           super_effective
# 250          super_effective                       NaN
#
#     ghost_attack_effectiveness dragon_attack_effectiveness  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 246                        NaN                         NaN
# 247         not_very_effective                         NaN
# 248            super_effective                         NaN
# 249                        NaN                         NaN
# 250            super_effective                         NaN
#
#     dark_attack_effectiveness steel_attack_effectiveness
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN         not_very_effective
# 4                         NaN         not_very_effective
# ..                        ...                        ...
# 246                       NaN            super_effective
# 247        not_very_effective            super_effective
# 248           super_effective                        NaN
# 249                       NaN         not_very_effective
# 250           super_effective                        NaN
#
# [251 rows x 31 columns]

# %%
## Create a sparse matrix for setting up Pokémon rules

new_df=pd.DataFrame(columns=pokemonNameList+itWeighsList+itHasHeightList+type1list+type2list+genusList+genIntroduceInList+legendaryornot+canEvolve+evolvesFromList+evolvesFromSomething+colorList+shapeList+isAshOwnedList+isPrimaryColorList+[item for sublist in effectiveList for item in sublist])
new_df['Pokemon']=data['name']
for ele in type1list:
    new_df[ele]=data['type_1'].apply(lambda x: 1 if x==ele.split(" ")[1] else 0)
for ele in type2list:
    new_df[ele]=data['type_2'].apply(lambda x: 1 if x==ele.split(" ")[1] else 0)
for ele in itWeighsList:
    if ele=="itWeighs veryLight":
        new_df[ele]=data['weight'].apply(lambda x: 1 if int(x)<int(itWeighsdict["veryLight"]) else 0)
    elif ele=="itWeighs veryHeavy":
        new_df[ele]=data['weight'].apply(lambda x: 1 if int(x)>int(itWeighsdict["veryHeavy"]) else 0)
for ele in itHasHeightList:
    if ele=="itHasHeight veryShort":
        new_df[ele]=data['height'].apply(lambda x: 1 if int(x)<int(itHasHeight["veryShort"]) else 0)
    elif ele=="itHasHeight veryTall":
        new_df[ele]=data['height'].apply(lambda x: 1 if int(x)>int(itHasHeight["veryTall"]) else 0)
for ele in genusList:
    new_df[ele]=data['genus'].apply(lambda x: 1 if ''.join(x.split(" ")[:-1])==ele.split(" ")[1] else 0)
for ele in genIntroduceInList:
    new_df[ele]=data['gen_introduced'].apply(lambda x: 1 if str(x)==str(ele.split(" ")[1][-1:]) else 0)
for ele in legendaryornot:
    new_df[ele]=data['legendary'].apply(lambda x: 1 if x==True else 0)
for ele in canEvolve:
    new_df[ele]=data['can_evolve'].apply(lambda x: 1 if x==True else 0)
for ele in evolvesFromList:
    new_df[ele]=data['evolves_from'].apply(lambda x: 1 if x==ele.split(" ")[1] else 0)
for ele in evolvesFromSomething:
    new_df[ele]=data['evolves_from'].apply(lambda x: 1 if str(x)!='nan' else 0)
for ele in colorList:
    new_df[ele]=data['primary_color'].apply(lambda x: 1 if x==ele.split(" ")[1] else 0)
for ele in shapeList:
    new_df[ele]=data['shape'].apply(lambda x: 1 if x==ele.split(" ")[1] else 0)
for ele in shapeList:
    new_df[ele]=data['shape'].apply(lambda x: 1 if x==ele.split(" ")[1] else 0)
for ele in shapeList:
    new_df[ele]=data['shape'].apply(lambda x: 1 if x==ele.split(" ")[1] else 0)
for ele in isPrimaryColorList:
    new_df[ele]=data['primary_color'].apply(lambda x: 1 if x.lower() in primaryColors else 0)
#flatten 2d howEffectiveList
howEffectiveList = [item for sublist in effectiveList for item in sublist]
for ele in howEffectiveList:
    new_df[ele]=data[ele.split(' ')[1].lower()+"_attack_effectiveness"].apply(lambda x: 1 if ele.split(" ")[2] in str(x) else 0)
ash_df = pd.read_csv('../data/PokemonOwnedbyAsh.csv')
for ele in isAshOwnedList:
    new_df[ele]=data['name'].apply(lambda x: 1 if x in ash_df['Pokemon'].values else 0)

# %%
new_df['evolvesFromSomething']
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 246    1
# 247    1
# 248    0
# 249    0
# 250    0
# Name: evolvesFromSomething, Length: 251, dtype: int64

# %%
# create rules from the sparse matrix for each Pokémon
# for example, rule: ((isColor Yellow) (isLegendary) … (isType Electric)) -> (isPokemon Zapdos)
rules = []
for i in range(len(new_df)):
    s = "("
    for j in range(len(new_df.columns)):
        if new_df.iloc[i,j] == 1 and new_df.columns[j] not in s:
            s += "("+new_df.columns[j]+")" + " "
    s+=")" + " -> " + "(" + "isPokemon " + new_df.iloc[i,0] + ")"
    rules.append(s)
rules
# Out:
# ['((isType Poison) (isGenus Seed) (wasIntroducedIn Gen1) (canEvolve) (isColor Green) (hasShape Quadruped) (isAshOwned) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) ) -> (isPokemon Bulbasaur)',
#  '((isType Poison) (isGenus Seed) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Bulbasaur) (evolvesFromSomething) (isColor Green) (hasShape Quadruped) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) ) -> (isPokemon Ivysaur)',
#  '((isType Poison) (isGenus Seed) (wasIntroducedIn Gen1) (evolvesFrom Ivysaur) (evolvesFromSomething) (isColor Green) (hasShape Quadruped) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) ) -> (isPokemon Venusaur)',
#  '((itHasHeight veryShort) (isGenus Lizard) (wasIntroducedIn Gen1) (canEvolve) (isColor Red) (hasShape Upright) (isAshOwned) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Charmander)',
#  '((isGenus Flame) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Charmander) (evolvesFromSomething) (isColor Red) (hasShape Upright) (isAshOwned) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Charmeleon)',
#  '((isType Flying) (isGenus Flame) (wasIntroducedIn Gen1) (evolvesFrom Charmeleon) (evolvesFromSomething) (isColor Red) (hasShape Upright) (isAshOwned) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Charizard)',
#  '((itHasHeight veryShort) (isGenus TinyTurtle) (wasIntroducedIn Gen1) (canEvolve) (isColor Blue) (hasShape Upright) (isAshOwned) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Squirtle)',
#  '((isGenus Turtle) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Squirtle) (evolvesFromSomething) (isColor Blue) (hasShape Upright) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Wartortle)',
#  '((isGenus Shellfish) (wasIntroducedIn Gen1) (evolvesFrom Wartortle) (evolvesFromSomething) (isColor Blue) (hasShape Upright) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Blastoise)',
#  '((itWeighs veryLight) (itHasHeight veryShort) (isType Bug) (isGenus Worm) (wasIntroducedIn Gen1) (canEvolve) (isColor Green) (hasShape Armor) (isAshOwned) (howEffective Fire super_effective) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Ground not_very_effective) (howEffective Fly super_effective) (howEffective Rock super_effective) ) -> (isPokemon Caterpie)',
#  '((isType Bug) (isGenus Cocoon) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Caterpie) (evolvesFromSomething) (isColor Green) (hasShape Squiggle) (isAshOwned) (howEffective Fire super_effective) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Ground not_very_effective) (howEffective Fly super_effective) (howEffective Rock super_effective) ) -> (isPokemon Metapod)',
#  '((isType Bug) (isType Flying) (isGenus Butterfly) (wasIntroducedIn Gen1) (evolvesFrom Metapod) (evolvesFromSomething) (isColor White) (hasShape Bug-Wings) (isAshOwned) (howEffective Fire super_effective) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Ground has_no_effect) (howEffective Fly super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) ) -> (isPokemon Butterfree)',
#  '((itWeighs veryLight) (itHasHeight veryShort) (isType Bug) (isType Poison) (isGenus HairyBug) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Armor) (howEffective Fire super_effective) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) ) -> (isPokemon Weedle)',
#  '((itHasHeight veryShort) (isType Bug) (isType Poison) (isGenus Cocoon) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Weedle) (evolvesFromSomething) (isColor Yellow) (hasShape Squiggle) (isPrimaryColor) (howEffective Fire super_effective) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) ) -> (isPokemon Kakuna)',
#  '((isType Bug) (isType Poison) (isGenus PoisonBee) (wasIntroducedIn Gen1) (evolvesFrom Kakuna) (evolvesFromSomething) (isColor Yellow) (hasShape Bug-Wings) (isPrimaryColor) (howEffective Fire super_effective) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) ) -> (isPokemon Beedrill)',
#  '((itWeighs veryLight) (itHasHeight veryShort) (isType Normal) (isType Flying) (isGenus TinyBird) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Wings) (isAshOwned) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Pidgey)',
#  '((isType Normal) (isType Flying) (isGenus Bird) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Pidgey) (evolvesFromSomething) (isColor Brown) (hasShape Wings) (isAshOwned) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Pidgeotto)',
#  '((isType Normal) (isType Flying) (isGenus Bird) (wasIntroducedIn Gen1) (evolvesFrom Pidgeotto) (evolvesFromSomething) (isColor Brown) (hasShape Wings) (isAshOwned) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Pidgeot)',
#  '((itWeighs veryLight) (itHasHeight veryShort) (isType Normal) (isGenus Mouse) (wasIntroducedIn Gen1) (canEvolve) (isColor Purple) (hasShape Quadruped) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Rattata)',
#  '((isType Normal) (isGenus Mouse) (wasIntroducedIn Gen1) (evolvesFrom Rattata) (evolvesFromSomething) (isColor Brown) (hasShape Quadruped) (isAshOwned) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Raticate)',
#  '((itWeighs veryLight) (itHasHeight veryShort) (isType Normal) (isType Flying) (isGenus TinyBird) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Wings) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Spearow)',
#  '((isType Normal) (isType Flying) (isGenus Beak) (wasIntroducedIn Gen1) (evolvesFrom Spearow) (evolvesFromSomething) (isColor Brown) (hasShape Wings) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Fearow)',
#  '((isGenus Snake) (wasIntroducedIn Gen1) (canEvolve) (isColor Purple) (hasShape Squiggle) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) ) -> (isPokemon Ekans)',
#  '((itHasHeight veryTall) (isGenus Cobra) (wasIntroducedIn Gen1) (evolvesFrom Ekans) (evolvesFromSomething) (isColor Purple) (hasShape Squiggle) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) ) -> (isPokemon Arbok)',
#  '((itHasHeight veryShort) (isGenus Mouse) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Pichu) (evolvesFromSomething) (isColor Yellow) (hasShape Quadruped) (isAshOwned) (isPrimaryColor) (howEffective Electric not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Pikachu)',
#  '((isGenus Mouse) (wasIntroducedIn Gen1) (evolvesFrom Pikachu) (evolvesFromSomething) (isColor Yellow) (hasShape Upright) (isPrimaryColor) (howEffective Electric not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Raichu)',
#  '((itHasHeight veryShort) (isGenus Mouse) (wasIntroducedIn Gen1) (canEvolve) (isColor Yellow) (hasShape Upright) (isPrimaryColor) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Poison not_very_effective) (howEffective Rock not_very_effective) ) -> (isPokemon Sandshrew)',
#  '((isGenus Mouse) (wasIntroducedIn Gen1) (evolvesFrom Sandshrew) (evolvesFromSomething) (isColor Yellow) (hasShape Upright) (isPrimaryColor) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Poison not_very_effective) (howEffective Rock not_very_effective) ) -> (isPokemon Sandslash)',
#  '((itHasHeight veryShort) (isGenus PoisonPin) (wasIntroducedIn Gen1) (isColor Blue) (hasShape Quadruped) (isPrimaryColor) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) ) -> (isPokemon Nidoran F)',
#  '((isGenus PoisonPin) (wasIntroducedIn Gen1) (canEvolve) (evolvesFromSomething) (isColor Blue) (hasShape Quadruped) (isPrimaryColor) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) ) -> (isPokemon Nidorina)',
#  '((isType Ground) (isGenus Drill) (wasIntroducedIn Gen1) (evolvesFrom Nidorina) (evolvesFromSomething) (isColor Blue) (hasShape Upright) (isPrimaryColor) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) ) -> (isPokemon Nidoqueen)',
#  '((itHasHeight veryShort) (isGenus PoisonPin) (wasIntroducedIn Gen1) (isColor Purple) (hasShape Quadruped) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) ) -> (isPokemon Nidoran M)',
#  '((isGenus PoisonPin) (wasIntroducedIn Gen1) (canEvolve) (evolvesFromSomething) (isColor Purple) (hasShape Quadruped) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) ) -> (isPokemon Nidorino)',
#  '((isType Ground) (isGenus Drill) (wasIntroducedIn Gen1) (evolvesFrom Nidorino) (evolvesFromSomething) (isColor Purple) (hasShape Upright) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) ) -> (isPokemon Nidoking)',
#  '((itHasHeight veryShort) (isGenus Fairy) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Cleffa) (evolvesFromSomething) (isColor Pink) (hasShape Upright) (howEffective Fighting not_very_effective) (howEffective Poison super_effective) (howEffective Bug not_very_effective) (howEffective Dragon has_no_effect) (howEffective Dark not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Clefairy)',
#  '((isGenus Fairy) (wasIntroducedIn Gen1) (evolvesFrom Clefairy) (evolvesFromSomething) (isColor Pink) (hasShape Upright) (howEffective Fighting not_very_effective) (howEffective Poison super_effective) (howEffective Bug not_very_effective) (howEffective Dragon has_no_effect) (howEffective Dark not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Clefable)',
#  '((itHasHeight veryShort) (isGenus Fox) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Quadruped) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Vulpix)',
#  '((isGenus Fox) (wasIntroducedIn Gen1) (evolvesFrom Vulpix) (evolvesFromSomething) (isColor Yellow) (hasShape Quadruped) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Ninetales)',
#  '((itHasHeight veryShort) (isType Normal) (isType Fairy) (isGenus Balloon) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Igglybuff) (evolvesFromSomething) (isColor Pink) (hasShape Humanoid) (howEffective Poison super_effective) (howEffective Bug not_very_effective) (howEffective Ghost has_no_effect) (howEffective Dragon has_no_effect) (howEffective Dark not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Jigglypuff)',
#  '((isType Normal) (isType Fairy) (isGenus Balloon) (wasIntroducedIn Gen1) (evolvesFrom Jigglypuff) (evolvesFromSomething) (isColor Pink) (hasShape Humanoid) (howEffective Poison super_effective) (howEffective Bug not_very_effective) (howEffective Ghost has_no_effect) (howEffective Dragon has_no_effect) (howEffective Dark not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Wigglytuff)',
#  '((isType Flying) (isGenus Bat) (wasIntroducedIn Gen1) (canEvolve) (isColor Purple) (hasShape Wings) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground has_no_effect) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) ) -> (isPokemon Zubat)',
#  '((isType Flying) (isGenus Bat) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Zubat) (evolvesFromSomething) (isColor Purple) (hasShape Wings) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground has_no_effect) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) ) -> (isPokemon Golbat)',
#  '((itHasHeight veryShort) (isType Poison) (isGenus Weed) (wasIntroducedIn Gen1) (canEvolve) (isColor Blue) (hasShape Legs) (isPrimaryColor) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) ) -> (isPokemon Oddish)',
#  '((isType Poison) (isGenus Weed) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Oddish) (evolvesFromSomething) (isColor Blue) (hasShape Humanoid) (isPrimaryColor) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) ) -> (isPokemon Gloom)',
#  '((isType Poison) (isGenus Flower) (wasIntroducedIn Gen1) (evolvesFrom Gloom) (evolvesFromSomething) (isColor Red) (hasShape Humanoid) (isPrimaryColor) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) ) -> (isPokemon Vileplume)',
#  '((itHasHeight veryShort) (isType Grass) (isType Bug) (isGenus Mushroom) (wasIntroducedIn Gen1) (canEvolve) (isColor Red) (hasShape Armor) (isPrimaryColor) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Poison super_effective) (howEffective Ground not_very_effective) (howEffective Fly super_effective) (howEffective Bug super_effective) (howEffective Rock super_effective) ) -> (isPokemon Paras)',
#  '((isType Grass) (isType Bug) (isGenus Mushroom) (wasIntroducedIn Gen1) (evolvesFrom Paras) (evolvesFromSomething) (isColor Red) (hasShape Armor) (isPrimaryColor) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Poison super_effective) (howEffective Ground not_very_effective) (howEffective Fly super_effective) (howEffective Bug super_effective) (howEffective Rock super_effective) ) -> (isPokemon Parasect)',
#  '((isType Bug) (isType Poison) (isGenus Insect) (wasIntroducedIn Gen1) (canEvolve) (isColor Purple) (hasShape Humanoid) (howEffective Fire super_effective) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) ) -> (isPokemon Venonat)',
#  '((isType Bug) (isType Poison) (isGenus PoisonMoth) (wasIntroducedIn Gen1) (evolvesFrom Venonat) (evolvesFromSomething) (isColor Purple) (hasShape Bug-Wings) (howEffective Fire super_effective) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) ) -> (isPokemon Venomoth)',
#  '((itWeighs veryLight) (itHasHeight veryShort) (isGenus Mole) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Blob) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Poison not_very_effective) (howEffective Rock not_very_effective) ) -> (isPokemon Diglett)',
#  '((isGenus Mole) (wasIntroducedIn Gen1) (evolvesFrom Diglett) (evolvesFromSomething) (isColor Brown) (hasShape Heads) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Poison not_very_effective) (howEffective Rock not_very_effective) ) -> (isPokemon Dugtrio)',
#  '((itWeighs veryLight) (itHasHeight veryShort) (isType Normal) (isGenus ScratchCat) (wasIntroducedIn Gen1) (canEvolve) (isColor Yellow) (hasShape Quadruped) (isPrimaryColor) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Meowth)',
#  '((isType Normal) (isGenus ClassyCat) (wasIntroducedIn Gen1) (evolvesFrom Meowth) (evolvesFromSomething) (isColor Yellow) (hasShape Quadruped) (isPrimaryColor) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Persian)',
#  '((isGenus Duck) (wasIntroducedIn Gen1) (canEvolve) (isColor Yellow) (hasShape Upright) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Psyduck)',
#  '((isGenus Duck) (wasIntroducedIn Gen1) (evolvesFrom Psyduck) (evolvesFromSomething) (isColor Blue) (hasShape Upright) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Golduck)',
#  '((itHasHeight veryShort) (isGenus PigMonkey) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Upright) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dark not_very_effective) ) -> (isPokemon Mankey)',
#  '((isGenus PigMonkey) (wasIntroducedIn Gen1) (evolvesFrom Mankey) (evolvesFromSomething) (isColor Brown) (hasShape Upright) (isAshOwned) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dark not_very_effective) ) -> (isPokemon Primeape)',
#  '((isGenus Puppy) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Quadruped) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Growlithe)',
#  '((itWeighs veryHeavy) (isGenus Legendary) (wasIntroducedIn Gen1) (evolvesFrom Growlithe) (evolvesFromSomething) (isColor Brown) (hasShape Quadruped) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Arcanine)',
#  '((itHasHeight veryShort) (isGenus Tadpole) (wasIntroducedIn Gen1) (canEvolve) (isColor Blue) (hasShape Legs) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Poliwag)',
#  '((isGenus Tadpole) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Poliwag) (evolvesFromSomething) (isColor Blue) (hasShape Humanoid) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Poliwhirl)',
#  '((isType Fighting) (isGenus Tadpole) (wasIntroducedIn Gen1) (evolvesFrom Poliwhirl) (evolvesFromSomething) (isColor Blue) (hasShape Humanoid) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dark not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Poliwrath)',
#  '((isGenus Psi) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Upright) (howEffective Fighting not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Abra)',
#  '((isGenus Psi) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Abra) (evolvesFromSomething) (isColor Brown) (hasShape Upright) (howEffective Fighting not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Kadabra)',
#  '((isGenus Psi) (wasIntroducedIn Gen1) (evolvesFrom Kadabra) (evolvesFromSomething) (isColor Brown) (hasShape Humanoid) (howEffective Fighting not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Alakazam)',
#  '((isGenus Superpower) (wasIntroducedIn Gen1) (canEvolve) (isColor Gray) (hasShape Upright) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dark not_very_effective) ) -> (isPokemon Machop)',
#  '((isGenus Superpower) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Machop) (evolvesFromSomething) (isColor Gray) (hasShape Humanoid) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dark not_very_effective) ) -> (isPokemon Machoke)',
#  '((itWeighs veryHeavy) (isGenus Superpower) (wasIntroducedIn Gen1) (evolvesFrom Machoke) (evolvesFromSomething) (isColor Gray) (hasShape Humanoid) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dark not_very_effective) ) -> (isPokemon Machamp)',
#  '((itWeighs veryLight) (isType Poison) (isGenus Flower) (wasIntroducedIn Gen1) (canEvolve) (isColor Green) (hasShape Humanoid) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) ) -> (isPokemon Bellsprout)',
#  '((isType Poison) (isGenus Flycatcher) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Bellsprout) (evolvesFromSomething) (isColor Green) (hasShape Blob) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) ) -> (isPokemon Weepinbell)',
#  '((isType Poison) (isGenus Flycatcher) (wasIntroducedIn Gen1) (evolvesFrom Weepinbell) (evolvesFromSomething) (isColor Green) (hasShape Blob) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Fly super_effective) (howEffective Psychic super_effective) ) -> (isPokemon Victreebel)',
#  '((isType Poison) (isGenus Jellyfish) (wasIntroducedIn Gen1) (canEvolve) (isColor Blue) (hasShape Tentacles) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Ice not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Tentacool)',
#  '((isType Poison) (isGenus Jellyfish) (wasIntroducedIn Gen1) (evolvesFrom Tentacool) (evolvesFromSomething) (isColor Blue) (hasShape Tentacles) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Ice not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Tentacruel)',
#  '((itHasHeight veryShort) (isType Ground) (isGenus Rock) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Arms) (howEffective Normal not_very_effective) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Rock not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Geodude)',
#  '((itWeighs veryHeavy) (isType Ground) (isGenus Rock) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Geodude) (evolvesFromSomething) (isColor Brown) (hasShape Humanoid) (howEffective Normal not_very_effective) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Rock not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Graveler)',
#  '((itWeighs veryHeavy) (isType Ground) (isGenus Megaton) (wasIntroducedIn Gen1) (evolvesFrom Graveler) (evolvesFromSomething) (isColor Brown) (hasShape Humanoid) (howEffective Normal not_very_effective) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Rock not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Golem)',
#  '((isGenus FireHorse) (wasIntroducedIn Gen1) (canEvolve) (isColor Yellow) (hasShape Quadruped) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Ponyta)',
#  '((isGenus FireHorse) (wasIntroducedIn Gen1) (evolvesFrom Ponyta) (evolvesFromSomething) (isColor Yellow) (hasShape Quadruped) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Rapidash)',
#  '((isType Psychic) (isGenus Dopey) (wasIntroducedIn Gen1) (canEvolve) (isColor Pink) (hasShape Quadruped) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Fighting not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Slowpoke)',
#  '((isType Psychic) (isGenus HermitCrab) (wasIntroducedIn Gen1) (evolvesFrom Slowpoke) (evolvesFromSomething) (isColor Pink) (hasShape Upright) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Fighting not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Slowbro)',
#  '((itHasHeight veryShort) (isType Steel) (isGenus Magnet) (wasIntroducedIn Gen1) (canEvolve) (isColor Gray) (hasShape Arms) (howEffective Normal not_very_effective) (howEffective Fire super_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Fighting super_effective) (howEffective Poison has_no_effect) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dragon not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Magnemite)',
#  '((isType Steel) (isGenus Magnet) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Magnemite) (evolvesFromSomething) (isColor Gray) (hasShape Heads) (howEffective Normal not_very_effective) (howEffective Fire super_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Fighting super_effective) (howEffective Poison has_no_effect) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dragon not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Magneton)',
#  '((isType Normal) (isType Flying) (isGenus WildDuck) (wasIntroducedIn Gen1) (isColor Brown) (hasShape Wings) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Farfetchd)',
#  '((isType Normal) (isType Flying) (isGenus TwinBird) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Legs) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Doduo)',
#  '((isType Normal) (isType Flying) (isGenus TripleBird) (wasIntroducedIn Gen1) (evolvesFrom Doduo) (evolvesFromSomething) (isColor Brown) (hasShape Legs) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Dodrio)',
#  '((isGenus SeaLion) (wasIntroducedIn Gen1) (canEvolve) (isColor White) (hasShape Fish) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Seel)',
#  '((itWeighs veryHeavy) (isType Ice) (isGenus SeaLion) (wasIntroducedIn Gen1) (evolvesFrom Seel) (evolvesFromSomething) (isColor White) (hasShape Fish) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Fighting super_effective) (howEffective Rock super_effective) ) -> (isPokemon Dewgong)',
#  '((isGenus Sludge) (wasIntroducedIn Gen1) (canEvolve) (isColor Purple) (hasShape Arms) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) ) -> (isPokemon Grimer)',
#  '((isGenus Sludge) (wasIntroducedIn Gen1) (evolvesFrom Grimer) (evolvesFromSomething) (isColor Purple) (hasShape Arms) (isAshOwned) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) ) -> (isPokemon Muk)',
#  '((itWeighs veryLight) (itHasHeight veryShort) (isGenus Bivalve) (wasIntroducedIn Gen1) (canEvolve) (isColor Purple) (hasShape Ball) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Shellder)',
#  '((itWeighs veryHeavy) (isType Ice) (isGenus Bivalve) (wasIntroducedIn Gen1) (evolvesFrom Shellder) (evolvesFromSomething) (isColor Purple) (hasShape Ball) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Fighting super_effective) (howEffective Rock super_effective) ) -> (isPokemon Cloyster)',
#  '((itWeighs veryLight) (isType Poison) (isType Ghost) (isGenus Gas) (wasIntroducedIn Gen1) (canEvolve) (isColor Purple) (hasShape Ball) (howEffective Normal has_no_effect) (howEffective Grass not_very_effective) (howEffective Fighting has_no_effect) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Gastly)',
#  '((itWeighs veryLight) (isType Poison) (isType Ghost) (isGenus Gas) (wasIntroducedIn Gen1) (canEvolve) (evolvesFrom Gastly) (evolvesFromSomething) (isColor Purple) (hasShape Arms) (howEffective Normal has_no_effect) (howEffective Grass not_very_effective) (howEffective Fighting has_no_effect) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Haunter)',
#  '((isType Poison) (isType Ghost) (isGenus Shadow) (wasIntroducedIn Gen1) (evolvesFrom Haunter) (evolvesFromSomething) (isColor Purple) (hasShape Upright) (howEffective Normal has_no_effect) (howEffective Grass not_very_effective) (howEffective Fighting has_no_effect) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Gengar)',
#  '((itWeighs veryHeavy) (itHasHeight veryTall) (isType Ground) (isGenus RockSnake) (wasIntroducedIn Gen1) (canEvolve) (isColor Gray) (hasShape Squiggle) (howEffective Normal not_very_effective) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Rock not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Onix)',
#  '((isGenus Hypnosis) (wasIntroducedIn Gen1) (canEvolve) (isColor Yellow) (hasShape Humanoid) (isPrimaryColor) (howEffective Fighting not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Drowzee)',
#  '((isGenus Hypnosis) (wasIntroducedIn Gen1) (evolvesFrom Drowzee) (evolvesFromSomething) (isColor Yellow) (hasShape Humanoid) (isPrimaryColor) (howEffective Fighting not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Hypno)',
#  '((itHasHeight veryShort) (isGenus RiverCrab) (wasIntroducedIn Gen1) (canEvolve) (isColor Red) (hasShape Armor) (isAshOwned) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Krabby)',
#  '((isGenus Pincer) (wasIntroducedIn Gen1) (evolvesFrom Krabby) (evolvesFromSomething) (isColor Red) (hasShape Armor) (isAshOwned) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Kingler)',
#  '((itHasHeight veryShort) (isGenus Ball) (wasIntroducedIn Gen1) (canEvolve) (isColor Red) (hasShape Ball) (isPrimaryColor) (howEffective Electric not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Voltorb)',
#  '((isGenus Ball) (wasIntroducedIn Gen1) (evolvesFrom Voltorb) (evolvesFromSomething) (isColor Red) (hasShape Ball) (isPrimaryColor) (howEffective Electric not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Electrode)',
#  '((itWeighs veryLight) (itHasHeight veryShort) (isType Psychic) (isGenus Egg) (wasIntroducedIn Gen1) (canEvolve) (isColor Pink) (hasShape Heads) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Poison super_effective) (howEffective Ground not_very_effective) (howEffective Fly super_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Exeggcute)',
#  '((itWeighs veryHeavy) (isType Psychic) (isGenus Coconut) (wasIntroducedIn Gen1) (evolvesFrom Exeggcute) (evolvesFromSomething) (isColor Yellow) (hasShape Legs) (isPrimaryColor) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Poison super_effective) (howEffective Ground not_very_effective) (howEffective Fly super_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Exeggutor)',
#  '((itHasHeight veryShort) (isGenus Lonely) (wasIntroducedIn Gen1) (canEvolve) (isColor Brown) (hasShape Upright) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Poison not_very_effective) (howEffective Rock not_very_effective) ) -> (isPokemon Cubone)',
#  '((isGenus BoneKeeper) (wasIntroducedIn Gen1) (evolvesFrom Cubone) (evolvesFromSomething) (isColor Brown) (hasShape Upright) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Poison not_very_effective) (howEffective Rock not_very_effective) ) -> (isPokemon Marowak)',
#  '((isGenus Kicking) (wasIntroducedIn Gen1) (evolvesFrom Tyrogue) (evolvesFromSomething) (isColor Brown) (hasShape Humanoid) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dark not_very_effective) ) -> (isPokemon Hitmonlee)',
#  '((isGenus Punching) (wasIntroducedIn Gen1) (evolvesFrom Tyrogue) (evolvesFromSomething) (isColor Brown) (hasShape Humanoid) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dark not_very_effective) ) -> (isPokemon Hitmonchan)',
# ...
#  '((isType Ice) (isGenus SharpClaw) (wasIntroducedIn Gen2) (canEvolve) (isColor Black) (hasShape Upright) (howEffective Fire super_effective) (howEffective Ice not_very_effective) (howEffective Fighting super_effective) (howEffective Psychic has_no_effect) (howEffective Bug super_effective) (howEffective Rock super_effective) (howEffective Ghost not_very_effective) (howEffective Dark not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Sneasel)',
#  '((itHasHeight veryShort) (isType Normal) (isGenus LittleBear) (wasIntroducedIn Gen2) (canEvolve) (isColor Brown) (hasShape Upright) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Teddiursa)',
#  '((itWeighs veryHeavy) (isType Normal) (isGenus Hibernator) (wasIntroducedIn Gen2) (evolvesFrom Teddiursa) (evolvesFromSomething) (isColor Brown) (hasShape Upright) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Ursaring)',
#  '((isGenus Lava) (wasIntroducedIn Gen2) (canEvolve) (isColor Red) (hasShape Squiggle) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Slugma)',
#  '((isType Rock) (isGenus Lava) (wasIntroducedIn Gen2) (evolvesFrom Slugma) (evolvesFromSomething) (isColor Red) (hasShape Squiggle) (isPrimaryColor) (howEffective Normal not_very_effective) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Ice not_very_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) ) -> (isPokemon Magcargo)',
#  '((itHasHeight veryShort) (isType Ground) (isGenus Pig) (wasIntroducedIn Gen2) (canEvolve) (isColor Brown) (hasShape Quadruped) (howEffective Fire super_effective) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Swinub)',
#  '((isType Ground) (isGenus Swine) (wasIntroducedIn Gen2) (canEvolve) (evolvesFrom Swinub) (evolvesFromSomething) (isColor Brown) (hasShape Quadruped) (howEffective Fire super_effective) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Piloswine)',
#  '((itHasHeight veryShort) (isType Rock) (isGenus Coral) (wasIntroducedIn Gen2) (canEvolve) (isColor Pink) (hasShape Armor) (howEffective Normal not_very_effective) (howEffective Fire not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) ) -> (isPokemon Corsola)',
#  '((itHasHeight veryShort) (isGenus Jet) (wasIntroducedIn Gen2) (canEvolve) (isColor Gray) (hasShape Fish) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Remoraid)',
#  '((isGenus Jet) (wasIntroducedIn Gen2) (evolvesFrom Remoraid) (evolvesFromSomething) (isColor Red) (hasShape Tentacles) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Octillery)',
#  '((isType Flying) (isGenus Delivery) (wasIntroducedIn Gen2) (isColor Red) (hasShape Wings) (isPrimaryColor) (howEffective Fire super_effective) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel super_effective) ) -> (isPokemon Delibird)',
#  '((itWeighs veryHeavy) (isType Flying) (isGenus Kite) (wasIntroducedIn Gen2) (evolvesFrom Mantyke) (evolvesFromSomething) (isColor Purple) (hasShape Wings) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Fighting not_very_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Mantine)',
#  '((isType Flying) (isGenus ArmorBird) (wasIntroducedIn Gen2) (isColor Gray) (hasShape Wings) (howEffective Normal not_very_effective) (howEffective Fire super_effective) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Poison has_no_effect) (howEffective Ground has_no_effect) (howEffective Fly not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug not_very_effective) (howEffective Dragon not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Skarmory)',
#  '((itHasHeight veryShort) (isType Fire) (isGenus Dark) (wasIntroducedIn Gen2) (canEvolve) (isColor Black) (hasShape Quadruped) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Fighting super_effective) (howEffective Ground super_effective) (howEffective Psychic has_no_effect) (howEffective Rock super_effective) (howEffective Ghost not_very_effective) (howEffective Dark not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Houndour)',
#  '((isType Fire) (isGenus Dark) (wasIntroducedIn Gen2) (evolvesFrom Houndour) (evolvesFromSomething) (isColor Black) (hasShape Quadruped) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Fighting super_effective) (howEffective Ground super_effective) (howEffective Psychic has_no_effect) (howEffective Rock super_effective) (howEffective Ghost not_very_effective) (howEffective Dark not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Houndoom)',
#  '((itWeighs veryHeavy) (isType Dragon) (isGenus Dragon) (wasIntroducedIn Gen2) (evolvesFrom Seadra) (evolvesFromSomething) (isColor Blue) (hasShape Blob) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Dragon super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Kingdra)',
#  '((itHasHeight veryShort) (isGenus LongNose) (wasIntroducedIn Gen2) (canEvolve) (isColor Blue) (hasShape Quadruped) (isAshOwned) (isPrimaryColor) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Poison not_very_effective) (howEffective Rock not_very_effective) ) -> (isPokemon Phanpy)',
#  '((itWeighs veryHeavy) (isGenus Armor) (wasIntroducedIn Gen2) (evolvesFrom Phanpy) (evolvesFromSomething) (isColor Gray) (hasShape Quadruped) (isAshOwned) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Poison not_very_effective) (howEffective Rock not_very_effective) ) -> (isPokemon Donphan)',
#  '((itHasHeight veryShort) (isType Normal) (isGenus Virtual) (wasIntroducedIn Gen2) (canEvolve) (evolvesFrom Porygon) (evolvesFromSomething) (isColor Red) (hasShape Legs) (isPrimaryColor) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Porygon2)',
#  '((isType Normal) (isGenus BigHorn) (wasIntroducedIn Gen2) (isColor Brown) (hasShape Quadruped) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Stantler)',
#  '((isType Normal) (isGenus Painter) (wasIntroducedIn Gen2) (isColor White) (hasShape Upright) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Smeargle)',
#  '((isGenus Scuffle) (wasIntroducedIn Gen2) (canEvolve) (isColor Purple) (hasShape Humanoid) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dark not_very_effective) ) -> (isPokemon Tyrogue)',
#  '((isGenus Handstand) (wasIntroducedIn Gen2) (evolvesFrom Tyrogue) (evolvesFromSomething) (isColor Brown) (hasShape Upright) (howEffective Fly super_effective) (howEffective Psychic super_effective) (howEffective Bug not_very_effective) (howEffective Rock not_very_effective) (howEffective Dark not_very_effective) ) -> (isPokemon Hitmontop)',
#  '((itHasHeight veryShort) (isType Psychic) (isGenus Kiss) (wasIntroducedIn Gen2) (canEvolve) (isColor Pink) (hasShape Humanoid) (howEffective Fire super_effective) (howEffective Ice not_very_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Rock super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) (howEffective Steel super_effective) ) -> (isPokemon Smoochum)',
#  '((itHasHeight veryShort) (isGenus Electric) (wasIntroducedIn Gen2) (canEvolve) (isColor Yellow) (hasShape Humanoid) (isPrimaryColor) (howEffective Electric not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Elekid)',
#  '((isGenus LiveCoal) (wasIntroducedIn Gen2) (canEvolve) (isColor Red) (hasShape Upright) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Magby)',
#  '((isType Normal) (isGenus MilkCow) (wasIntroducedIn Gen2) (isColor Pink) (hasShape Upright) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Miltank)',
#  '((isType Normal) (isGenus Happiness) (wasIntroducedIn Gen2) (evolvesFrom Chansey) (evolvesFromSomething) (isColor Pink) (hasShape Humanoid) (howEffective Fighting super_effective) (howEffective Ghost has_no_effect) ) -> (isPokemon Blissey)',
#  '((itWeighs veryHeavy) (isGenus Thunder) (wasIntroducedIn Gen2) (isLegendary) (isColor Yellow) (hasShape Quadruped) (isPrimaryColor) (howEffective Electric not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Raikou)',
#  '((itWeighs veryHeavy) (isGenus Volcano) (wasIntroducedIn Gen2) (isLegendary) (isColor Brown) (hasShape Quadruped) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass not_very_effective) (howEffective Ice not_very_effective) (howEffective Ground super_effective) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Entei)',
#  '((itWeighs veryHeavy) (isGenus Aurora) (wasIntroducedIn Gen2) (isLegendary) (isColor Blue) (hasShape Quadruped) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water not_very_effective) (howEffective Electric super_effective) (howEffective Grass super_effective) (howEffective Ice not_very_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Suicune)',
#  '((itHasHeight veryShort) (isType Ground) (isGenus RockSkin) (wasIntroducedIn Gen2) (canEvolve) (isColor Green) (hasShape Upright) (isAshOwned) (howEffective Normal not_very_effective) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Rock not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Larvitar)',
#  '((itWeighs veryHeavy) (isType Ground) (isGenus HardShell) (wasIntroducedIn Gen2) (canEvolve) (evolvesFrom Larvitar) (evolvesFromSomething) (isColor Gray) (hasShape Squiggle) (howEffective Normal not_very_effective) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Electric has_no_effect) (howEffective Grass super_effective) (howEffective Ice super_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Rock not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Pupitar)',
#  '((itWeighs veryHeavy) (isType Dark) (isGenus Armor) (wasIntroducedIn Gen2) (evolvesFrom Pupitar) (evolvesFromSomething) (isColor Green) (hasShape Upright) (howEffective Normal not_very_effective) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Grass super_effective) (howEffective Fighting super_effective) (howEffective Poison not_very_effective) (howEffective Ground super_effective) (howEffective Fly not_very_effective) (howEffective Psychic has_no_effect) (howEffective Bug super_effective) (howEffective Ghost not_very_effective) (howEffective Dark not_very_effective) (howEffective Steel super_effective) ) -> (isPokemon Tyranitar)',
#  '((itWeighs veryHeavy) (itHasHeight veryTall) (isType Flying) (isGenus Diving) (wasIntroducedIn Gen2) (isLegendary) (isColor White) (hasShape Wings) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Ground has_no_effect) (howEffective Psychic not_very_effective) (howEffective Rock super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Lugia)',
#  '((itWeighs veryHeavy) (itHasHeight veryTall) (isType Flying) (isGenus Rainbow) (wasIntroducedIn Gen2) (isLegendary) (isColor Red) (hasShape Wings) (isPrimaryColor) (howEffective Fire not_very_effective) (howEffective Water super_effective) (howEffective Electric super_effective) (howEffective Grass not_very_effective) (howEffective Fighting not_very_effective) (howEffective Ground has_no_effect) (howEffective Bug not_very_effective) (howEffective Rock super_effective) (howEffective Steel not_very_effective) ) -> (isPokemon Ho Oh)',
#  '((itHasHeight veryShort) (isType Grass) (isGenus TimeTravel) (wasIntroducedIn Gen2) (isColor Green) (hasShape Humanoid) (howEffective Fire super_effective) (howEffective Water not_very_effective) (howEffective Electric not_very_effective) (howEffective Grass not_very_effective) (howEffective Ice super_effective) (howEffective Fighting not_very_effective) (howEffective Poison super_effective) (howEffective Ground not_very_effective) (howEffective Fly super_effective) (howEffective Psychic not_very_effective) (howEffective Bug super_effective) (howEffective Ghost super_effective) (howEffective Dark super_effective) ) -> (isPokemon Celebi)']
